# %%
import numpy as np

# Network architecture
n = [2, 3, 3, 1] # Number of neurons in each layer
print("layer 0 / input layer size", n[0])
print("layer 1 size", n[1])
print("layer 2 size", n[2])
print("layer 3 / output layer size", n[3])
# Out:
# layer 0 / input layer size 2
# layer 1 size 3
# layer 2 size 3
# layer 3 size 1

# %%
# Weights and biases
W1 = np.random.randn(n[1], n[0])
W2 = np.random.randn(n[2], n[1])
W3 = np.random.randn(n[3], n[2])
b1 = np.random.randn(n[1], 1)
b2 = np.random.randn(n[2], 1)
b3 = np.random.randn(n[3], 1)

# Print the shapes of weights and biases
print("W1 shape:", W1.shape)
print("W2 shape:", W2.shape)
print("W3 shape:", W3.shape)
print("b1 shape:", b1.shape)
print("b2 shape:", b2.shape)
print("b3 shape:", b3.shape)
# Out:
# W1 shape: (3, 2)
# W2 shape: (3, 3)
# W3 shape: (1, 3)
# b1 shape: (3, 1)
# b2 shape: (3, 1)
# b3 shape: (1, 1)

# %%
W1
# Out:
# array([[ 1.7940783 ,  0.00982233],
#        [-0.01466632, -1.58426696],
#        [ 0.69800218, -0.50279805]])

# %%
# Example input
X = np.array([
    [150, 70],
    [254, 73],
    [312, 68],
    [120, 60],
    [154, 61],
    [212, 65],
    [216, 65],
    [145, 67],
    [184, 64],
    [130, 69]
])
print(X.shape)
# Out:
# (10, 2)

# %%
# Transpose training data
A_theta = X.T
print(A_theta.shape)
# Out:
# (2, 10)

# %%
# Training labels
y = np.array([
    0,
    1,
    1,
    0,
    0,
    1,
    1,
    0,
    1,
    0
])
m = 10

# Reshape labels to match output layer
Y = y.reshape(n[3], m)
Y.shape
# Out:
# (1, 10)
